# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, TensorDataset
from torchvision.models import resnet50, ResNet50_Weights
import os
from sklearn.model_selection import train_test_split
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Runing on {str(device)}")

# Define dataset paths
data_dir = "./animals10"
torch_dataset_path = "./animals10DatasetNoNormalize.pt"

# Define class names
class_names = ["cane", "cavallo", "elefante", "farfalla", "gallina", "gatto", "mucca", "pecora", "ragno", "scoiattolo"]
class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}
num_classes = len(class_names)

# Load dataset from Torch tensor file
print("Loading dataset from Torch tensor file...")
data = torch.load(torch_dataset_path)
images, labels = data["images"], data["labels"]

dataset = TensorDataset(images, labels)
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

print(f"Train samples: {len(train_dataset)}, Val samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
# Out:
# Runing on cuda
# Loading dataset from Torch tensor file...
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_54592\1008683256.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(torch_dataset_path)
# Train samples: 18325, Val samples: 3926, Test samples: 3928

# %%
# Create DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        
        # Convolutional feature extractor
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (3, 224, 224) -> (32, 112, 112)
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (32, 112, 112) -> (64, 56, 56)
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (64, 56, 56) -> (128, 28, 28)
        )

        self.classifier = nn.Sequential(
            nn.Linear(128 * 28 * 28, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )
    
    def forward(self, x):
        x = self.features(x)               # extract features through conv layers
        x = x.view(x.size(0), -1)         # flatten for the classifier
        x = self.classifier(x)            # final classification
        return x

# %%
model = SimpleCNN(num_classes=num_classes)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Adjust as needed

epochs = 100

# %%
def plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs):
    """
    Plots the training/validation loss and accuracy curves in separate charts.
    """
    # Plot loss
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss per Epoch')
    plt.legend()
    plt.show()

    # Plot accuracy
    plt.figure()
    plt.plot(train_accs, label='Train Acc')
    plt.plot(val_accs, label='Val Acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Epoch')
    plt.legend()
    plt.show()

# %%
train_losses = []
train_accs   = []
val_losses   = []
val_accs     = []

for epoch in range(epochs):
    # --- Training ---
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images_batch, labels_batch in train_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        loss.backward()
        optimizer.step()
        
        # Track training loss
        running_loss += loss.item() * images_batch.size(0)
        
        # Compute training accuracy
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels_batch).sum().item()
        total += labels_batch.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = correct / total

    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)
    
    print(f"Epoch [{epoch+1}/{epochs}] - "
          f"Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}")

    # --- Validation ---
    model.eval()
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for images_batch, labels_batch in val_loader:
            images_batch = images_batch.to(device)
            labels_batch = labels_batch.to(device)

            outputs = model(images_batch)
            loss = criterion(outputs, labels_batch)
            
            # Track validation loss
            val_running_loss += loss.item() * images_batch.size(0)
            # Compute validation accuracy
            _, predicted = outputs.max(1)
            val_correct += predicted.eq(labels_batch).sum().item()
            val_total += labels_batch.size(0)
    
    val_epoch_loss = val_running_loss / len(val_loader.dataset)
    val_epoch_acc = val_correct / val_total
    
    val_losses.append(val_epoch_loss)
    val_accs.append(val_epoch_acc)
    
    print(f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.4f}\n")
# Out:
# Epoch [1/100] - Train Loss: 1.9664, Train Acc: 0.3020
# Val Loss: 1.6809, Val Acc: 0.4238
#
# Epoch [2/100] - Train Loss: 1.6187, Train Acc: 0.4379
# Val Loss: 1.4729, Val Acc: 0.5094
#
# Epoch [3/100] - Train Loss: 1.4387, Train Acc: 0.5100
# Val Loss: 1.3270, Val Acc: 0.5624
#
# Epoch [4/100] - Train Loss: 1.3060, Train Acc: 0.5545
# Val Loss: 1.2551, Val Acc: 0.5782
#
# Epoch [5/100] - Train Loss: 1.2021, Train Acc: 0.5892
# Val Loss: 1.2181, Val Acc: 0.5922
#
# Epoch [6/100] - Train Loss: 1.0959, Train Acc: 0.6247
# Val Loss: 1.2174, Val Acc: 0.5914
#
# Epoch [7/100] - Train Loss: 1.0151, Train Acc: 0.6528
# Val Loss: 1.1298, Val Acc: 0.6182
#
# Epoch [8/100] - Train Loss: 0.9280, Train Acc: 0.6846
# Val Loss: 1.1319, Val Acc: 0.6281
#
# Epoch [9/100] - Train Loss: 0.8408, Train Acc: 0.7136
# Val Loss: 1.1172, Val Acc: 0.6358
#
# Epoch [10/100] - Train Loss: 0.7654, Train Acc: 0.7386
# Val Loss: 1.1380, Val Acc: 0.6319
#
# Epoch [11/100] - Train Loss: 0.6886, Train Acc: 0.7605
# Val Loss: 1.1535, Val Acc: 0.6370
#
# Epoch [12/100] - Train Loss: 0.6193, Train Acc: 0.7863
# Val Loss: 1.2108, Val Acc: 0.6322
#
# Epoch [13/100] - Train Loss: 0.5618, Train Acc: 0.8047
# Val Loss: 1.1944, Val Acc: 0.6454
#
# Epoch [14/100] - Train Loss: 0.5064, Train Acc: 0.8244
# Val Loss: 1.1743, Val Acc: 0.6442
#
# Epoch [15/100] - Train Loss: 0.4447, Train Acc: 0.8417
# Val Loss: 1.2267, Val Acc: 0.6467
#
# Epoch [16/100] - Train Loss: 0.4019, Train Acc: 0.8602
# Val Loss: 1.2670, Val Acc: 0.6513
#
# Epoch [17/100] - Train Loss: 0.3698, Train Acc: 0.8712
# Val Loss: 1.2970, Val Acc: 0.6355
#
# Epoch [18/100] - Train Loss: 0.3207, Train Acc: 0.8917
# Val Loss: 1.4046, Val Acc: 0.6434
#
# Epoch [19/100] - Train Loss: 0.2955, Train Acc: 0.8964
# Val Loss: 1.3605, Val Acc: 0.6460
#
# Epoch [20/100] - Train Loss: 0.2753, Train Acc: 0.9067
# Val Loss: 1.4408, Val Acc: 0.6434
#
# Epoch [21/100] - Train Loss: 0.2534, Train Acc: 0.9112
# Val Loss: 1.5953, Val Acc: 0.6363
#
# Epoch [22/100] - Train Loss: 0.2308, Train Acc: 0.9188
# Val Loss: 1.5641, Val Acc: 0.6391
#
# Epoch [23/100] - Train Loss: 0.2112, Train Acc: 0.9264
# Val Loss: 1.5164, Val Acc: 0.6521
#
# Epoch [24/100] - Train Loss: 0.2045, Train Acc: 0.9285
# Val Loss: 1.6934, Val Acc: 0.6342
#
# Epoch [25/100] - Train Loss: 0.1875, Train Acc: 0.9347
# Val Loss: 1.7574, Val Acc: 0.6460
#
# Epoch [26/100] - Train Loss: 0.1803, Train Acc: 0.9370
# Val Loss: 1.7637, Val Acc: 0.6493
#
# Epoch [27/100] - Train Loss: 0.1628, Train Acc: 0.9427
# Val Loss: 1.8383, Val Acc: 0.6403
#
# Epoch [28/100] - Train Loss: 0.1579, Train Acc: 0.9487
# Val Loss: 1.7718, Val Acc: 0.6431
#
# Epoch [29/100] - Train Loss: 0.1528, Train Acc: 0.9488
# Val Loss: 1.8187, Val Acc: 0.6419
#
# Epoch [30/100] - Train Loss: 0.1446, Train Acc: 0.9488
# Val Loss: 1.8731, Val Acc: 0.6411
#
# Epoch [31/100] - Train Loss: 0.1344, Train Acc: 0.9523
# Val Loss: 1.9639, Val Acc: 0.6393
#
# Epoch [32/100] - Train Loss: 0.1278, Train Acc: 0.9550
# Val Loss: 1.9872, Val Acc: 0.6393
#
# Epoch [33/100] - Train Loss: 0.1288, Train Acc: 0.9544
# Val Loss: 2.0465, Val Acc: 0.6460
#
# Epoch [34/100] - Train Loss: 0.1256, Train Acc: 0.9577
# Val Loss: 2.0692, Val Acc: 0.6452
#
# Epoch [35/100] - Train Loss: 0.1166, Train Acc: 0.9591
# Val Loss: 2.2145, Val Acc: 0.6365
#
# Epoch [36/100] - Train Loss: 0.1086, Train Acc: 0.9610
# Val Loss: 2.1769, Val Acc: 0.6403
#
# Epoch [37/100] - Train Loss: 0.1107, Train Acc: 0.9601
# Val Loss: 2.1379, Val Acc: 0.6454
#
# Epoch [38/100] - Train Loss: 0.1043, Train Acc: 0.9628
# Val Loss: 2.2491, Val Acc: 0.6426
#
# Epoch [39/100] - Train Loss: 0.1020, Train Acc: 0.9637
# Val Loss: 2.2096, Val Acc: 0.6444
#
# Epoch [40/100] - Train Loss: 0.0958, Train Acc: 0.9652
# Val Loss: 2.2813, Val Acc: 0.6368
#
# Epoch [41/100] - Train Loss: 0.0976, Train Acc: 0.9640
# Val Loss: 2.1858, Val Acc: 0.6391
#
# Epoch [42/100] - Train Loss: 0.0969, Train Acc: 0.9660
# Val Loss: 2.2547, Val Acc: 0.6449
#
# Epoch [43/100] - Train Loss: 0.0882, Train Acc: 0.9697
# Val Loss: 2.1716, Val Acc: 0.6421
#
# Epoch [44/100] - Train Loss: 0.0901, Train Acc: 0.9682
# Val Loss: 2.2286, Val Acc: 0.6409
#
# Epoch [45/100] - Train Loss: 0.0892, Train Acc: 0.9689
# Val Loss: 2.3798, Val Acc: 0.6439
#
# Epoch [46/100] - Train Loss: 0.0920, Train Acc: 0.9673
# Val Loss: 2.2968, Val Acc: 0.6378
#
# Epoch [47/100] - Train Loss: 0.0878, Train Acc: 0.9704
# Val Loss: 2.3068, Val Acc: 0.6424
#
# Epoch [48/100] - Train Loss: 0.0814, Train Acc: 0.9711
# Val Loss: 2.3221, Val Acc: 0.6431
#
# Epoch [49/100] - Train Loss: 0.0778, Train Acc: 0.9722
# Val Loss: 2.3796, Val Acc: 0.6322
#
# Epoch [50/100] - Train Loss: 0.0788, Train Acc: 0.9720
# Val Loss: 2.5672, Val Acc: 0.6337
#
# Epoch [51/100] - Train Loss: 0.0788, Train Acc: 0.9718
# Val Loss: 2.3844, Val Acc: 0.6431
#
# Epoch [52/100] - Train Loss: 0.0708, Train Acc: 0.9759
# Val Loss: 2.4208, Val Acc: 0.6401
#
# Epoch [53/100] - Train Loss: 0.0857, Train Acc: 0.9704
# Val Loss: 2.5051, Val Acc: 0.6437
#
# Epoch [54/100] - Train Loss: 0.0752, Train Acc: 0.9747
# Val Loss: 2.5510, Val Acc: 0.6378
#
# Epoch [55/100] - Train Loss: 0.0684, Train Acc: 0.9747
# Val Loss: 2.3503, Val Acc: 0.6411
#
# Epoch [56/100] - Train Loss: 0.0670, Train Acc: 0.9752
# Val Loss: 2.5269, Val Acc: 0.6368
#
# Epoch [57/100] - Train Loss: 0.0713, Train Acc: 0.9734
# Val Loss: 2.5286, Val Acc: 0.6434
#
# Epoch [58/100] - Train Loss: 0.0676, Train Acc: 0.9759
# Val Loss: 2.4587, Val Acc: 0.6409
#
# Epoch [59/100] - Train Loss: 0.0643, Train Acc: 0.9768
# Val Loss: 2.9248, Val Acc: 0.6296
#
# Epoch [60/100] - Train Loss: 0.0659, Train Acc: 0.9765
# Val Loss: 2.5321, Val Acc: 0.6375
#
# Epoch [61/100] - Train Loss: 0.0691, Train Acc: 0.9758
# Val Loss: 2.4664, Val Acc: 0.6429
#
# Epoch [62/100] - Train Loss: 0.0657, Train Acc: 0.9776
# Val Loss: 2.4913, Val Acc: 0.6475
#
# Epoch [63/100] - Train Loss: 0.0611, Train Acc: 0.9785
# Val Loss: 2.7874, Val Acc: 0.6363
#
# Epoch [64/100] - Train Loss: 0.0559, Train Acc: 0.9805
# Val Loss: 2.4993, Val Acc: 0.6490
#
# Epoch [65/100] - Train Loss: 0.0546, Train Acc: 0.9804
# Val Loss: 2.4902, Val Acc: 0.6429
#
# Epoch [66/100] - Train Loss: 0.0584, Train Acc: 0.9787
# Val Loss: 2.6003, Val Acc: 0.6437
#
# Epoch [67/100] - Train Loss: 0.0575, Train Acc: 0.9798
# Val Loss: 2.8665, Val Acc: 0.6381
#
# Epoch [68/100] - Train Loss: 0.0619, Train Acc: 0.9785
# Val Loss: 2.6085, Val Acc: 0.6409
#
# Epoch [69/100] - Train Loss: 0.0534, Train Acc: 0.9818
# Val Loss: 2.7965, Val Acc: 0.6500
#
# Epoch [70/100] - Train Loss: 0.0552, Train Acc: 0.9804
# Val Loss: 2.7953, Val Acc: 0.6368
#
# Epoch [71/100] - Train Loss: 0.0577, Train Acc: 0.9794
# Val Loss: 2.7852, Val Acc: 0.6401
#
# Epoch [72/100] - Train Loss: 0.0580, Train Acc: 0.9795
# Val Loss: 2.6903, Val Acc: 0.6396
#
# Epoch [73/100] - Train Loss: 0.0506, Train Acc: 0.9825
# Val Loss: 2.5418, Val Acc: 0.6442
#
# Epoch [74/100] - Train Loss: 0.0481, Train Acc: 0.9824
# Val Loss: 2.9201, Val Acc: 0.6475
#
# Epoch [75/100] - Train Loss: 0.0466, Train Acc: 0.9843
# Val Loss: 2.7280, Val Acc: 0.6442
#
# Epoch [76/100] - Train Loss: 0.0465, Train Acc: 0.9843
# Val Loss: 2.8575, Val Acc: 0.6452
#
# Epoch [77/100] - Train Loss: 0.0515, Train Acc: 0.9825
# Val Loss: 2.7060, Val Acc: 0.6437
#
# Epoch [78/100] - Train Loss: 0.0511, Train Acc: 0.9819
# Val Loss: 2.9721, Val Acc: 0.6434
#
# Epoch [79/100] - Train Loss: 0.0478, Train Acc: 0.9838
# Val Loss: 2.6989, Val Acc: 0.6457
#
# Epoch [80/100] - Train Loss: 0.0478, Train Acc: 0.9842
# Val Loss: 3.0246, Val Acc: 0.6373
#
# Epoch [81/100] - Train Loss: 0.0435, Train Acc: 0.9846
# Val Loss: 2.7330, Val Acc: 0.6365
#
# Epoch [82/100] - Train Loss: 0.0526, Train Acc: 0.9817
# Val Loss: 2.7252, Val Acc: 0.6424
#
# Epoch [83/100] - Train Loss: 0.0445, Train Acc: 0.9835
# Val Loss: 2.8155, Val Acc: 0.6424
#
# Epoch [84/100] - Train Loss: 0.0478, Train Acc: 0.9839
# Val Loss: 2.9797, Val Acc: 0.6304
#
# Epoch [85/100] - Train Loss: 0.0492, Train Acc: 0.9831
# Val Loss: 2.8663, Val Acc: 0.6449
#
# Epoch [86/100] - Train Loss: 0.0443, Train Acc: 0.9838
# Val Loss: 2.9376, Val Acc: 0.6482
#
# Epoch [87/100] - Train Loss: 0.0433, Train Acc: 0.9849
# Val Loss: 3.0421, Val Acc: 0.6322
#
# Epoch [88/100] - Train Loss: 0.0449, Train Acc: 0.9842
# Val Loss: 2.9466, Val Acc: 0.6426
#
# Epoch [89/100] - Train Loss: 0.0412, Train Acc: 0.9859
# Val Loss: 3.0333, Val Acc: 0.6368
#
# Epoch [90/100] - Train Loss: 0.0422, Train Acc: 0.9846
# Val Loss: 3.1481, Val Acc: 0.6442
#
# Epoch [91/100] - Train Loss: 0.0423, Train Acc: 0.9847
# Val Loss: 3.0895, Val Acc: 0.6467
#
# Epoch [92/100] - Train Loss: 0.0432, Train Acc: 0.9849
# Val Loss: 2.8303, Val Acc: 0.6460
#
# Epoch [93/100] - Train Loss: 0.0374, Train Acc: 0.9868
# Val Loss: 2.9594, Val Acc: 0.6508
#
# Epoch [94/100] - Train Loss: 0.0440, Train Acc: 0.9844
# Val Loss: 3.0205, Val Acc: 0.6495
#
# Epoch [95/100] - Train Loss: 0.0379, Train Acc: 0.9866
# Val Loss: 3.0117, Val Acc: 0.6434
#
# Epoch [96/100] - Train Loss: 0.0409, Train Acc: 0.9855
# Val Loss: 3.1925, Val Acc: 0.6429
#
# Epoch [97/100] - Train Loss: 0.0374, Train Acc: 0.9870
# Val Loss: 3.0895, Val Acc: 0.6500
#
# Epoch [98/100] - Train Loss: 0.0388, Train Acc: 0.9858
# Val Loss: 3.0666, Val Acc: 0.6513
#
# Epoch [99/100] - Train Loss: 0.0363, Train Acc: 0.9869
# Val Loss: 2.9101, Val Acc: 0.6406
#
# Epoch [100/100] - Train Loss: 0.0396, Train Acc: 0.9865
# Val Loss: 2.8714, Val Acc: 0.6416

# %%
# Plot Loss and Accuracy
plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs)

# %%
# Testing
model.eval()
test_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():
    for images_batch, labels_batch in test_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        
        test_loss += loss.item() * images_batch.size(0)
        _, predicted = outputs.max(1)
        test_correct += predicted.eq(labels_batch).sum().item()
        test_total += labels_batch.size(0)

test_loss /= len(test_loader.dataset)
test_acc = test_correct / test_total
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 3.0099, Test Acc: 0.6349
