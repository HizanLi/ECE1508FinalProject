# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, TensorDataset
from torchvision.models import resnet50, ResNet50_Weights
import os
from sklearn.model_selection import train_test_split
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Runing on {str(device)}")

# Define dataset paths
torch_train_path = "./animals90TrainDataset.pt"
torch_test_path = "./animals90TestDataset.pt"
torch_val_path = "./animals90ValDataset.pt"

# Define class names
class_names =  [
    "antelope", "badger", "bat", "bear", "bee", "beetle", "bison", "boar", "butterfly",
    "cat", "caterpillar", "chimpanzee", "cockroach", "cow", "coyote", "crab", "crow",
    "deer", "dog", "dolphin", "donkey", "dragonfly", "duck", "eagle", "elephant",
    "flamingo", "fly", "fox", "goat", "goldfish", "goose", "gorilla", "grasshopper",
    "hamster", "hare", "hedgehog", "hippopotamus", "hornbill", "horse", "hummingbird",
    "hyena", "jellyfish", "kangaroo", "koala", "ladybugs", "leopard", "lion", "lizard",
    "lobster", "mosquito", "moth", "mouse", "octopus", "okapi", "orangutan", "otter",
    "owl", "ox", "oyster", "panda", "parrot", "pelecaniformes", "penguin", "pig",
    "pigeon", "porcupine", "possum", "raccoon", "rat", "reindeer", "rhinoceros",
    "sandpiper", "seahorse", "seal", "shark", "sheep", "snake", "sparrow", "squid",
    "squirrel", "starfish", "swan", "tiger", "turkey", "turtle", "whale", "wolf",
    "wombat", "woodpecker", "zebra"
]
class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}
num_classes = len(class_names)

# Load dataset from Torch tensor file
print("Loading dataset from Torch tensor file...")
train_data = torch.load(torch_train_path)
print("Dataset loaded successfully.")
test_data = torch.load(torch_test_path)
print("Test dataset loaded successfully.")
val_dataset = torch.load(torch_val_path)
print("Validation dataset loaded successfully.")
train_images, train_labels = train_data["images"], train_data["labels"]
test_images, test_labels = test_data["images"], test_data["labels"]
val_images, val_labels = val_dataset["images"], val_dataset["labels"]

train_dataset = TensorDataset(train_images, train_labels)
test_dataset = TensorDataset(test_images, test_labels)
val_dataset = TensorDataset(val_images, val_labels)

print(f"Train samples: {len(train_dataset)}, Val samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
# Out:
# Runing on cpu
# Loading dataset from Torch tensor file...
# Dataset loaded successfully.
# Test dataset loaded successfully.
# Validation dataset loaded successfully.
# Train samples: 4320, Val samples: 1080, Test samples: 100

# %%
# Create DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        
        # Convolutional feature extractor
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (3, 224, 224) -> (32, 112, 112)
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (32, 112, 112) -> (64, 56, 56)
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (64, 56, 56) -> (128, 28, 28)
        )

        self.classifier = nn.Sequential(
            nn.Linear(128 * 28 * 28, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )
    
    def forward(self, x):
        x = self.features(x)               # extract features through conv layers
        x = x.view(x.size(0), -1)         # flatten for the classifier
        x = self.classifier(x)            # final classification
        return x

# %%
model = SimpleCNN(num_classes=num_classes)
model.to(device)
print(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Adjust as needed

epochs = 100

# %%
def plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs):
    """
    Plots the training/validation loss and accuracy curves in separate charts.
    """
    # Plot loss
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss per Epoch')
    plt.legend()
    plt.show()

    # Plot accuracy
    plt.figure()
    plt.plot(train_accs, label='Train Acc')
    plt.plot(val_accs, label='Val Acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Epoch')
    plt.legend()
    plt.show()

# %%
train_losses = []
train_accs   = []
val_losses   = []
val_accs     = []

for epoch in range(epochs):
    # --- Training ---
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images_batch, labels_batch in train_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        loss.backward()
        optimizer.step()
        
        # Track training loss
        running_loss += loss.item() * images_batch.size(0)
        
        # Compute training accuracy
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels_batch).sum().item()
        total += labels_batch.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = correct / total

    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)
    
    print(f"Epoch [{epoch+1}/{epochs}] - "
          f"Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}")

    # --- Validation ---
    model.eval()
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for images_batch, labels_batch in val_loader:
            images_batch = images_batch.to(device)
            labels_batch = labels_batch.to(device)

            outputs = model(images_batch)
            loss = criterion(outputs, labels_batch)
            
            # Track validation loss
            val_running_loss += loss.item() * images_batch.size(0)
            # Compute validation accuracy
            _, predicted = outputs.max(1)
            val_correct += predicted.eq(labels_batch).sum().item()
            val_total += labels_batch.size(0)
    
    val_epoch_loss = val_running_loss / len(val_loader.dataset)
    val_epoch_acc = val_correct / val_total
    
    val_losses.append(val_epoch_loss)
    val_accs.append(val_epoch_acc)
    
    print(f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.4f}\n")
# Out:
# Epoch [1/100] - Train Loss: 4.5037, Train Acc: 0.0215
# Val Loss: 4.3964, Val Acc: 0.0352
#
# Epoch [2/100] - Train Loss: 4.3606, Train Acc: 0.0387
# Val Loss: 4.2863, Val Acc: 0.0648
#
# Epoch [3/100] - Train Loss: 4.1814, Train Acc: 0.0701
# Val Loss: 4.1184, Val Acc: 0.1000
#
# Epoch [4/100] - Train Loss: 3.8743, Train Acc: 0.1187
# Val Loss: 3.9227, Val Acc: 0.1472
#
# Epoch [5/100] - Train Loss: 3.4477, Train Acc: 0.1998
# Val Loss: 3.6651, Val Acc: 0.2194
#
# Epoch [6/100] - Train Loss: 2.8966, Train Acc: 0.2972
# Val Loss: 3.5258, Val Acc: 0.2509
#
# Epoch [7/100] - Train Loss: 2.3845, Train Acc: 0.3995
# Val Loss: 3.3575, Val Acc: 0.2981
#
# Epoch [8/100] - Train Loss: 1.9347, Train Acc: 0.4926
# Val Loss: 3.3180, Val Acc: 0.3194
#
# Epoch [9/100] - Train Loss: 1.5719, Train Acc: 0.5764
# Val Loss: 3.2926, Val Acc: 0.3296
#
# Epoch [10/100] - Train Loss: 1.2281, Train Acc: 0.6562
# Val Loss: 3.2897, Val Acc: 0.3380
#
# Epoch [11/100] - Train Loss: 1.0004, Train Acc: 0.7194
# Val Loss: 3.4692, Val Acc: 0.3500
#
# Epoch [12/100] - Train Loss: 0.8697, Train Acc: 0.7500
# Val Loss: 3.5318, Val Acc: 0.3444
#
# Epoch [13/100] - Train Loss: 0.7440, Train Acc: 0.7822
# Val Loss: 3.6118, Val Acc: 0.3444
#
# Epoch [14/100] - Train Loss: 0.6403, Train Acc: 0.8090
# Val Loss: 3.7131, Val Acc: 0.3481
#
# Epoch [15/100] - Train Loss: 0.5918, Train Acc: 0.8238
# Val Loss: 3.6419, Val Acc: 0.3500
#
# Epoch [16/100] - Train Loss: 0.5357, Train Acc: 0.8389
# Val Loss: 3.7637, Val Acc: 0.3463
#
# Epoch [17/100] - Train Loss: 0.4782, Train Acc: 0.8572
# Val Loss: 3.9737, Val Acc: 0.3407
#
# Epoch [18/100] - Train Loss: 0.4228, Train Acc: 0.8671
# Val Loss: 4.0329, Val Acc: 0.3407
#
# Epoch [19/100] - Train Loss: 0.4003, Train Acc: 0.8806
# Val Loss: 4.0684, Val Acc: 0.3435
#
# Epoch [20/100] - Train Loss: 0.3971, Train Acc: 0.8762
# Val Loss: 4.1586, Val Acc: 0.3361
#
# Epoch [21/100] - Train Loss: 0.3541, Train Acc: 0.8944
# Val Loss: 4.3437, Val Acc: 0.3380
#
# Epoch [22/100] - Train Loss: 0.3309, Train Acc: 0.8951
# Val Loss: 4.2552, Val Acc: 0.3519
#
# Epoch [23/100] - Train Loss: 0.3324, Train Acc: 0.8951
# Val Loss: 4.3677, Val Acc: 0.3361
#
# Epoch [24/100] - Train Loss: 0.3446, Train Acc: 0.8907
# Val Loss: 4.3560, Val Acc: 0.3370
#
# Epoch [25/100] - Train Loss: 0.2973, Train Acc: 0.9044
# Val Loss: 4.4991, Val Acc: 0.3426
#
# Epoch [26/100] - Train Loss: 0.2868, Train Acc: 0.9056
# Val Loss: 4.5778, Val Acc: 0.3407
#
# Epoch [27/100] - Train Loss: 0.2813, Train Acc: 0.9106
# Val Loss: 4.7178, Val Acc: 0.3454
#
# Epoch [28/100] - Train Loss: 0.2936, Train Acc: 0.9106
# Val Loss: 4.6355, Val Acc: 0.3454
#
# Epoch [29/100] - Train Loss: 0.2823, Train Acc: 0.9100
# Val Loss: 4.5601, Val Acc: 0.3454
#
# Epoch [30/100] - Train Loss: 0.2463, Train Acc: 0.9262
# Val Loss: 4.5316, Val Acc: 0.3417
#
# Epoch [31/100] - Train Loss: 0.2398, Train Acc: 0.9176
# Val Loss: 4.7959, Val Acc: 0.3407
#
# Epoch [32/100] - Train Loss: 0.2379, Train Acc: 0.9201
# Val Loss: 4.8841, Val Acc: 0.3500
#
# Epoch [33/100] - Train Loss: 0.2479, Train Acc: 0.9164
# Val Loss: 5.0382, Val Acc: 0.3398
#
# Epoch [34/100] - Train Loss: 0.2381, Train Acc: 0.9227
# Val Loss: 4.8935, Val Acc: 0.3435
#
# Epoch [35/100] - Train Loss: 0.2086, Train Acc: 0.9361
# Val Loss: 5.1414, Val Acc: 0.3407
#
# Epoch [36/100] - Train Loss: 0.2225, Train Acc: 0.9266
# Val Loss: 5.1712, Val Acc: 0.3472
#
# Epoch [37/100] - Train Loss: 0.2265, Train Acc: 0.9280
# Val Loss: 5.0958, Val Acc: 0.3296
#
# Epoch [38/100] - Train Loss: 0.2139, Train Acc: 0.9308
# Val Loss: 5.3405, Val Acc: 0.3352
#
# Epoch [39/100] - Train Loss: 0.2139, Train Acc: 0.9280
# Val Loss: 5.1540, Val Acc: 0.3463
#
# Epoch [40/100] - Train Loss: 0.1997, Train Acc: 0.9350
# Val Loss: 5.1764, Val Acc: 0.3463
#
# Epoch [41/100] - Train Loss: 0.1831, Train Acc: 0.9417
# Val Loss: 5.2086, Val Acc: 0.3343
#
# Epoch [42/100] - Train Loss: 0.1917, Train Acc: 0.9417
# Val Loss: 5.1499, Val Acc: 0.3380
#
# Epoch [43/100] - Train Loss: 0.1956, Train Acc: 0.9338
# Val Loss: 5.1442, Val Acc: 0.3407
#
# Epoch [44/100] - Train Loss: 0.1812, Train Acc: 0.9400
# Val Loss: 5.2196, Val Acc: 0.3444
#
# Epoch [45/100] - Train Loss: 0.1724, Train Acc: 0.9407
# Val Loss: 5.3016, Val Acc: 0.3361
#
# Epoch [46/100] - Train Loss: 0.1883, Train Acc: 0.9352
# Val Loss: 5.3301, Val Acc: 0.3426
#
# Epoch [47/100] - Train Loss: 0.1865, Train Acc: 0.9414
# Val Loss: 5.2081, Val Acc: 0.3352
#
# Epoch [48/100] - Train Loss: 0.1776, Train Acc: 0.9400
# Val Loss: 5.2409, Val Acc: 0.3398
#
# Epoch [49/100] - Train Loss: 0.1691, Train Acc: 0.9463
# Val Loss: 5.1584, Val Acc: 0.3352
#
# Epoch [50/100] - Train Loss: 0.1650, Train Acc: 0.9470
# Val Loss: 5.4388, Val Acc: 0.3435
#
# Epoch [51/100] - Train Loss: 0.1546, Train Acc: 0.9505
# Val Loss: 5.5937, Val Acc: 0.3315
#
# Epoch [52/100] - Train Loss: 0.1577, Train Acc: 0.9468
# Val Loss: 5.8075, Val Acc: 0.3389
#
# Epoch [53/100] - Train Loss: 0.1689, Train Acc: 0.9421
# Val Loss: 5.4906, Val Acc: 0.3315
#
# Epoch [54/100] - Train Loss: 0.1691, Train Acc: 0.9444
# Val Loss: 5.3460, Val Acc: 0.3389
#
# Epoch [55/100] - Train Loss: 0.1666, Train Acc: 0.9414
# Val Loss: 5.6589, Val Acc: 0.3259
#
# Epoch [56/100] - Train Loss: 0.1530, Train Acc: 0.9516
# Val Loss: 5.7404, Val Acc: 0.3306
#
# Epoch [57/100] - Train Loss: 0.1601, Train Acc: 0.9472
# Val Loss: 5.5502, Val Acc: 0.3324
#
# Epoch [58/100] - Train Loss: 0.1456, Train Acc: 0.9523
# Val Loss: 5.8308, Val Acc: 0.3370
#
# Epoch [59/100] - Train Loss: 0.1690, Train Acc: 0.9451
# Val Loss: 5.6142, Val Acc: 0.3361
#
# Epoch [60/100] - Train Loss: 0.1704, Train Acc: 0.9419
# Val Loss: 5.4505, Val Acc: 0.3343
#
# Epoch [61/100] - Train Loss: 0.1391, Train Acc: 0.9551
# Val Loss: 5.6715, Val Acc: 0.3333
#
# Epoch [62/100] - Train Loss: 0.1575, Train Acc: 0.9449
# Val Loss: 5.4231, Val Acc: 0.3361
#
# Epoch [63/100] - Train Loss: 0.1358, Train Acc: 0.9586
# Val Loss: 5.5208, Val Acc: 0.3398
#
# Epoch [64/100] - Train Loss: 0.1373, Train Acc: 0.9530
# Val Loss: 5.9794, Val Acc: 0.3417
#
# Epoch [65/100] - Train Loss: 0.1546, Train Acc: 0.9468
# Val Loss: 5.4054, Val Acc: 0.3407
#
# Epoch [66/100] - Train Loss: 0.1581, Train Acc: 0.9488
# Val Loss: 5.8289, Val Acc: 0.3417
#
# Epoch [67/100] - Train Loss: 0.1265, Train Acc: 0.9567
# Val Loss: 5.5884, Val Acc: 0.3343
#
# Epoch [68/100] - Train Loss: 0.1282, Train Acc: 0.9565
# Val Loss: 5.5460, Val Acc: 0.3472
#
# Epoch [69/100] - Train Loss: 0.1545, Train Acc: 0.9528
# Val Loss: 5.5981, Val Acc: 0.3380
#
# Epoch [70/100] - Train Loss: 0.1273, Train Acc: 0.9572
# Val Loss: 5.7411, Val Acc: 0.3333
#
# Epoch [71/100] - Train Loss: 0.1319, Train Acc: 0.9576
# Val Loss: 5.6229, Val Acc: 0.3426
#
# Epoch [72/100] - Train Loss: 0.1376, Train Acc: 0.9530
# Val Loss: 5.7288, Val Acc: 0.3454
#
# Epoch [73/100] - Train Loss: 0.1314, Train Acc: 0.9537
# Val Loss: 5.8696, Val Acc: 0.3417
#
# Epoch [74/100] - Train Loss: 0.1362, Train Acc: 0.9549
# Val Loss: 5.6805, Val Acc: 0.3352
#
# Epoch [75/100] - Train Loss: 0.1263, Train Acc: 0.9576
# Val Loss: 5.6168, Val Acc: 0.3380
#
# Epoch [76/100] - Train Loss: 0.1314, Train Acc: 0.9567
# Val Loss: 5.8671, Val Acc: 0.3546
#
# Epoch [77/100] - Train Loss: 0.1249, Train Acc: 0.9567
# Val Loss: 5.8972, Val Acc: 0.3444
#
# Epoch [78/100] - Train Loss: 0.1208, Train Acc: 0.9569
# Val Loss: 5.7632, Val Acc: 0.3565
#
# Epoch [79/100] - Train Loss: 0.1110, Train Acc: 0.9602
# Val Loss: 5.9669, Val Acc: 0.3472
#
# Epoch [80/100] - Train Loss: 0.1214, Train Acc: 0.9567
# Val Loss: 5.8466, Val Acc: 0.3417
#
# Epoch [81/100] - Train Loss: 0.1181, Train Acc: 0.9625
# Val Loss: 5.9966, Val Acc: 0.3481
#
# Epoch [82/100] - Train Loss: 0.1276, Train Acc: 0.9569
# Val Loss: 5.8193, Val Acc: 0.3491
#
# Epoch [83/100] - Train Loss: 0.1169, Train Acc: 0.9586
# Val Loss: 6.4142, Val Acc: 0.3296
#
# Epoch [84/100] - Train Loss: 0.1206, Train Acc: 0.9600
# Val Loss: 6.4127, Val Acc: 0.3435
#
# Epoch [85/100] - Train Loss: 0.1162, Train Acc: 0.9620
# Val Loss: 5.7647, Val Acc: 0.3463
#
# Epoch [86/100] - Train Loss: 0.1135, Train Acc: 0.9639
# Val Loss: 6.0905, Val Acc: 0.3287
#
# Epoch [87/100] - Train Loss: 0.1317, Train Acc: 0.9611
# Val Loss: 5.8642, Val Acc: 0.3370
#
# Epoch [88/100] - Train Loss: 0.1153, Train Acc: 0.9616
# Val Loss: 5.7448, Val Acc: 0.3250
#
# Epoch [89/100] - Train Loss: 0.1106, Train Acc: 0.9669
# Val Loss: 5.9766, Val Acc: 0.3407
#
# Epoch [90/100] - Train Loss: 0.1081, Train Acc: 0.9660
# Val Loss: 6.2489, Val Acc: 0.3463
#
# Epoch [91/100] - Train Loss: 0.1220, Train Acc: 0.9579
# Val Loss: 6.2336, Val Acc: 0.3454
#
# Epoch [92/100] - Train Loss: 0.1208, Train Acc: 0.9595
# Val Loss: 5.6306, Val Acc: 0.3407
#
# Epoch [93/100] - Train Loss: 0.1154, Train Acc: 0.9655
# Val Loss: 6.0908, Val Acc: 0.3333
#
# Epoch [94/100] - Train Loss: 0.1157, Train Acc: 0.9644
# Val Loss: 5.9997, Val Acc: 0.3444
#
# Epoch [95/100] - Train Loss: 0.1140, Train Acc: 0.9600
# Val Loss: 6.1790, Val Acc: 0.3315
#
# Epoch [96/100] - Train Loss: 0.1147, Train Acc: 0.9613
# Val Loss: 5.9274, Val Acc: 0.3444
#
# Epoch [97/100] - Train Loss: 0.1011, Train Acc: 0.9657
# Val Loss: 6.1087, Val Acc: 0.3426
#
# Epoch [98/100] - Train Loss: 0.1122, Train Acc: 0.9600
# Val Loss: 6.1576, Val Acc: 0.3426
#
# Epoch [99/100] - Train Loss: 0.1103, Train Acc: 0.9627
# Val Loss: 6.0963, Val Acc: 0.3361
#
# Epoch [100/100] - Train Loss: 0.1033, Train Acc: 0.9653
# Val Loss: 6.0926, Val Acc: 0.3491

# %%
# Plot Loss and Accuracy
plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs)

# %%
# Testing
model.eval()
test_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():
    for images_batch, labels_batch in test_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        
        test_loss += loss.item() * images_batch.size(0)
        _, predicted = outputs.max(1)
        test_correct += predicted.eq(labels_batch).sum().item()
        test_total += labels_batch.size(0)

test_loss /= len(test_loader.dataset)
test_acc = test_correct / test_total
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 8.3073, Test Acc: 0.1000
