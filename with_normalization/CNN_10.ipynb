# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, TensorDataset
from torchvision.models import resnet50, ResNet50_Weights
import os
from sklearn.model_selection import train_test_split
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f"Runing on {str(device)}")

# Define dataset paths
data_dir = "./animals10"
torch_dataset_path = "./animals10Dataset.pt"

# Define class names
class_names = ["cane", "cavallo", "elefante", "farfalla", "gallina", "gatto", "mucca", "pecora", "ragno", "scoiattolo"]
class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}
num_classes = len(class_names)

# Load dataset from Torch tensor file
print("Loading dataset from Torch tensor file...")
data = torch.load(torch_dataset_path)
images, labels = data["images"], data["labels"]

dataset = TensorDataset(images, labels)
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])

print(f"Train samples: {len(train_dataset)}, Val samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
# Out:
# Runing on cuda
# Loading dataset from Torch tensor file...
# C:\Users\Hizan\AppData\Local\Temp\ipykernel_29844\2429660180.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(torch_dataset_path)
# Train samples: 18325, Val samples: 3926, Test samples: 3928

# %%
# Create DataLoaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleCNN, self).__init__()
        
        # Convolutional feature extractor
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (3, 224, 224) -> (32, 112, 112)
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (32, 112, 112) -> (64, 56, 56)
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),  # (64, 56, 56) -> (128, 28, 28)
        )

        self.classifier = nn.Sequential(
            nn.Linear(128 * 28 * 28, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )
    
    def forward(self, x):
        x = self.features(x)               # extract features through conv layers
        x = x.view(x.size(0), -1)         # flatten for the classifier
        x = self.classifier(x)            # final classification
        return x

# %%
model = SimpleCNN(num_classes=num_classes)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)  # Adjust as needed

epochs = 100

# %%
def plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs):
    """
    Plots the training/validation loss and accuracy curves in separate charts.
    """
    # Plot loss
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss per Epoch')
    plt.legend()
    plt.show()

    # Plot accuracy
    plt.figure()
    plt.plot(train_accs, label='Train Acc')
    plt.plot(val_accs, label='Val Acc')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Epoch')
    plt.legend()
    plt.show()

# %%
train_losses = []
train_accs   = []
val_losses   = []
val_accs     = []

for epoch in range(epochs):
    # --- Training ---
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images_batch, labels_batch in train_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        loss.backward()
        optimizer.step()
        
        # Track training loss
        running_loss += loss.item() * images_batch.size(0)
        
        # Compute training accuracy
        _, predicted = outputs.max(1)
        correct += predicted.eq(labels_batch).sum().item()
        total += labels_batch.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = correct / total

    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)
    
    print(f"Epoch [{epoch+1}/{epochs}] - "
          f"Train Loss: {epoch_loss:.4f}, Train Acc: {epoch_acc:.4f}")

    # --- Validation ---
    model.eval()
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for images_batch, labels_batch in val_loader:
            images_batch = images_batch.to(device)
            labels_batch = labels_batch.to(device)

            outputs = model(images_batch)
            loss = criterion(outputs, labels_batch)
            
            # Track validation loss
            val_running_loss += loss.item() * images_batch.size(0)
            # Compute validation accuracy
            _, predicted = outputs.max(1)
            val_correct += predicted.eq(labels_batch).sum().item()
            val_total += labels_batch.size(0)
    
    val_epoch_loss = val_running_loss / len(val_loader.dataset)
    val_epoch_acc = val_correct / val_total
    
    val_losses.append(val_epoch_loss)
    val_accs.append(val_epoch_acc)
    
    print(f"Val Loss: {val_epoch_loss:.4f}, Val Acc: {val_epoch_acc:.4f}\n")
# Out:
# Epoch [1/100] - Train Loss: 1.8694, Train Acc: 0.3412
# Val Loss: 1.5925, Val Acc: 0.4567
#
# Epoch [2/100] - Train Loss: 1.5565, Train Acc: 0.4604
# Val Loss: 1.4381, Val Acc: 0.5227
#
# Epoch [3/100] - Train Loss: 1.4216, Train Acc: 0.5115
# Val Loss: 1.3784, Val Acc: 0.5153
#
# Epoch [4/100] - Train Loss: 1.3127, Train Acc: 0.5533
# Val Loss: 1.2699, Val Acc: 0.5688
#
# Epoch [5/100] - Train Loss: 1.1975, Train Acc: 0.5895
# Val Loss: 1.2008, Val Acc: 0.5953
#
# Epoch [6/100] - Train Loss: 1.1024, Train Acc: 0.6241
# Val Loss: 1.1619, Val Acc: 0.6067
#
# Epoch [7/100] - Train Loss: 1.0126, Train Acc: 0.6536
# Val Loss: 1.1224, Val Acc: 0.6325
#
# Epoch [8/100] - Train Loss: 0.9165, Train Acc: 0.6856
# Val Loss: 1.0903, Val Acc: 0.6409
#
# Epoch [9/100] - Train Loss: 0.8290, Train Acc: 0.7100
# Val Loss: 1.0994, Val Acc: 0.6431
#
# Epoch [10/100] - Train Loss: 0.7577, Train Acc: 0.7348
# Val Loss: 1.0760, Val Acc: 0.6485
#
# Epoch [11/100] - Train Loss: 0.6726, Train Acc: 0.7683
# Val Loss: 1.1071, Val Acc: 0.6508
#
# Epoch [12/100] - Train Loss: 0.5903, Train Acc: 0.8002
# Val Loss: 1.1090, Val Acc: 0.6630
#
# Epoch [13/100] - Train Loss: 0.5304, Train Acc: 0.8180
# Val Loss: 1.1566, Val Acc: 0.6528
#
# Epoch [14/100] - Train Loss: 0.4609, Train Acc: 0.8409
# Val Loss: 1.1960, Val Acc: 0.6582
#
# Epoch [15/100] - Train Loss: 0.4128, Train Acc: 0.8565
# Val Loss: 1.2260, Val Acc: 0.6531
#
# Epoch [16/100] - Train Loss: 0.3628, Train Acc: 0.8730
# Val Loss: 1.2344, Val Acc: 0.6635
#
# Epoch [17/100] - Train Loss: 0.3191, Train Acc: 0.8875
# Val Loss: 1.2750, Val Acc: 0.6574
#
# Epoch [18/100] - Train Loss: 0.2852, Train Acc: 0.9020
# Val Loss: 1.3500, Val Acc: 0.6651
#
# Epoch [19/100] - Train Loss: 0.2601, Train Acc: 0.9072
# Val Loss: 1.3309, Val Acc: 0.6559
#
# Epoch [20/100] - Train Loss: 0.2314, Train Acc: 0.9223
# Val Loss: 1.4476, Val Acc: 0.6582
#
# Epoch [21/100] - Train Loss: 0.2160, Train Acc: 0.9245
# Val Loss: 1.4824, Val Acc: 0.6587
#
# Epoch [22/100] - Train Loss: 0.2008, Train Acc: 0.9300
# Val Loss: 1.5234, Val Acc: 0.6587
#
# Epoch [23/100] - Train Loss: 0.1817, Train Acc: 0.9369
# Val Loss: 1.6037, Val Acc: 0.6549
#
# Epoch [24/100] - Train Loss: 0.1691, Train Acc: 0.9393
# Val Loss: 1.6455, Val Acc: 0.6503
#
# Epoch [25/100] - Train Loss: 0.1657, Train Acc: 0.9441
# Val Loss: 1.6574, Val Acc: 0.6584
#
# Epoch [26/100] - Train Loss: 0.1439, Train Acc: 0.9517
# Val Loss: 1.6817, Val Acc: 0.6620
#
# Epoch [27/100] - Train Loss: 0.1437, Train Acc: 0.9506
# Val Loss: 1.7701, Val Acc: 0.6633
#
# Epoch [28/100] - Train Loss: 0.1250, Train Acc: 0.9546
# Val Loss: 1.7853, Val Acc: 0.6615
#
# Epoch [29/100] - Train Loss: 0.1277, Train Acc: 0.9541
# Val Loss: 1.7682, Val Acc: 0.6482
#
# Epoch [30/100] - Train Loss: 0.1229, Train Acc: 0.9556
# Val Loss: 1.8671, Val Acc: 0.6508
#
# Epoch [31/100] - Train Loss: 0.1125, Train Acc: 0.9615
# Val Loss: 1.8557, Val Acc: 0.6602
#
# Epoch [32/100] - Train Loss: 0.1120, Train Acc: 0.9599
# Val Loss: 1.9224, Val Acc: 0.6651
#
# Epoch [33/100] - Train Loss: 0.1116, Train Acc: 0.9607
# Val Loss: 1.9461, Val Acc: 0.6518
#
# Epoch [34/100] - Train Loss: 0.1037, Train Acc: 0.9626
# Val Loss: 1.8746, Val Acc: 0.6615
#
# Epoch [35/100] - Train Loss: 0.0924, Train Acc: 0.9680
# Val Loss: 1.8989, Val Acc: 0.6620
#
# Epoch [36/100] - Train Loss: 0.0982, Train Acc: 0.9658
# Val Loss: 2.0017, Val Acc: 0.6656
#
# Epoch [37/100] - Train Loss: 0.0853, Train Acc: 0.9699
# Val Loss: 2.0625, Val Acc: 0.6584
#
# Epoch [38/100] - Train Loss: 0.0872, Train Acc: 0.9701
# Val Loss: 2.0626, Val Acc: 0.6572
#
# Epoch [39/100] - Train Loss: 0.0877, Train Acc: 0.9680
# Val Loss: 2.0016, Val Acc: 0.6648
#
# Epoch [40/100] - Train Loss: 0.0891, Train Acc: 0.9688
# Val Loss: 1.9275, Val Acc: 0.6605
#
# Epoch [41/100] - Train Loss: 0.0774, Train Acc: 0.9737
# Val Loss: 2.2324, Val Acc: 0.6633
#
# Epoch [42/100] - Train Loss: 0.0790, Train Acc: 0.9738
# Val Loss: 2.0269, Val Acc: 0.6597
#
# Epoch [43/100] - Train Loss: 0.0794, Train Acc: 0.9726
# Val Loss: 2.0906, Val Acc: 0.6574
#
# Epoch [44/100] - Train Loss: 0.0763, Train Acc: 0.9723
# Val Loss: 2.2392, Val Acc: 0.6648
#
# Epoch [45/100] - Train Loss: 0.0715, Train Acc: 0.9752
# Val Loss: 2.1717, Val Acc: 0.6605
#
# Epoch [46/100] - Train Loss: 0.0705, Train Acc: 0.9747
# Val Loss: 2.2213, Val Acc: 0.6633
#
# Epoch [47/100] - Train Loss: 0.0678, Train Acc: 0.9764
# Val Loss: 2.4302, Val Acc: 0.6615
#
# Epoch [48/100] - Train Loss: 0.0746, Train Acc: 0.9735
# Val Loss: 2.2310, Val Acc: 0.6564
#
# Epoch [49/100] - Train Loss: 0.0674, Train Acc: 0.9755
# Val Loss: 2.2774, Val Acc: 0.6615
#
# Epoch [50/100] - Train Loss: 0.0617, Train Acc: 0.9782
# Val Loss: 2.4832, Val Acc: 0.6556
#
# Epoch [51/100] - Train Loss: 0.0669, Train Acc: 0.9753
# Val Loss: 2.2350, Val Acc: 0.6546
#
# Epoch [52/100] - Train Loss: 0.0576, Train Acc: 0.9797
# Val Loss: 2.4573, Val Acc: 0.6579
#
# Epoch [53/100] - Train Loss: 0.0619, Train Acc: 0.9786
# Val Loss: 2.2998, Val Acc: 0.6625
#
# Epoch [54/100] - Train Loss: 0.0595, Train Acc: 0.9783
# Val Loss: 2.4115, Val Acc: 0.6651
#
# Epoch [55/100] - Train Loss: 0.0646, Train Acc: 0.9768
# Val Loss: 2.2786, Val Acc: 0.6651
#
# Epoch [56/100] - Train Loss: 0.0583, Train Acc: 0.9794
# Val Loss: 2.3517, Val Acc: 0.6572
#
# Epoch [57/100] - Train Loss: 0.0584, Train Acc: 0.9801
# Val Loss: 2.4995, Val Acc: 0.6612
#
# Epoch [58/100] - Train Loss: 0.0529, Train Acc: 0.9818
# Val Loss: 2.4447, Val Acc: 0.6594
#
# Epoch [59/100] - Train Loss: 0.0592, Train Acc: 0.9790
# Val Loss: 2.3628, Val Acc: 0.6673
#
# Epoch [60/100] - Train Loss: 0.0559, Train Acc: 0.9804
# Val Loss: 2.3149, Val Acc: 0.6671
#
# Epoch [61/100] - Train Loss: 0.0580, Train Acc: 0.9804
# Val Loss: 2.5255, Val Acc: 0.6663
#
# Epoch [62/100] - Train Loss: 0.0519, Train Acc: 0.9815
# Val Loss: 2.6138, Val Acc: 0.6630
#
# Epoch [63/100] - Train Loss: 0.0482, Train Acc: 0.9819
# Val Loss: 2.4030, Val Acc: 0.6651
#
# Epoch [64/100] - Train Loss: 0.0524, Train Acc: 0.9820
# Val Loss: 2.5800, Val Acc: 0.6684
#
# Epoch [65/100] - Train Loss: 0.0552, Train Acc: 0.9801
# Val Loss: 2.3912, Val Acc: 0.6610
#
# Epoch [66/100] - Train Loss: 0.0502, Train Acc: 0.9825
# Val Loss: 2.6058, Val Acc: 0.6597
#
# Epoch [67/100] - Train Loss: 0.0491, Train Acc: 0.9834
# Val Loss: 2.5100, Val Acc: 0.6638
#
# Epoch [68/100] - Train Loss: 0.0494, Train Acc: 0.9826
# Val Loss: 2.5559, Val Acc: 0.6561
#
# Epoch [69/100] - Train Loss: 0.0501, Train Acc: 0.9827
# Val Loss: 2.5337, Val Acc: 0.6574
#
# Epoch [70/100] - Train Loss: 0.0495, Train Acc: 0.9818
# Val Loss: 2.4318, Val Acc: 0.6623
#
# Epoch [71/100] - Train Loss: 0.0450, Train Acc: 0.9848
# Val Loss: 2.4108, Val Acc: 0.6661
#
# Epoch [72/100] - Train Loss: 0.0422, Train Acc: 0.9840
# Val Loss: 2.7162, Val Acc: 0.6589
#
# Epoch [73/100] - Train Loss: 0.0436, Train Acc: 0.9844
# Val Loss: 2.6637, Val Acc: 0.6551
#
# Epoch [74/100] - Train Loss: 0.0433, Train Acc: 0.9843
# Val Loss: 2.6787, Val Acc: 0.6623
#
# Epoch [75/100] - Train Loss: 0.0419, Train Acc: 0.9844
# Val Loss: 2.5603, Val Acc: 0.6633
#
# Epoch [76/100] - Train Loss: 0.0392, Train Acc: 0.9854
# Val Loss: 2.7025, Val Acc: 0.6676
#
# Epoch [77/100] - Train Loss: 0.0421, Train Acc: 0.9850
# Val Loss: 2.6181, Val Acc: 0.6673
#
# Epoch [78/100] - Train Loss: 0.0447, Train Acc: 0.9836
# Val Loss: 2.6325, Val Acc: 0.6686
#
# Epoch [79/100] - Train Loss: 0.0451, Train Acc: 0.9843
# Val Loss: 2.6260, Val Acc: 0.6689
#
# Epoch [80/100] - Train Loss: 0.0423, Train Acc: 0.9848
# Val Loss: 2.6935, Val Acc: 0.6676
#
# Epoch [81/100] - Train Loss: 0.0362, Train Acc: 0.9870
# Val Loss: 2.9817, Val Acc: 0.6572
#
# Epoch [82/100] - Train Loss: 0.0310, Train Acc: 0.9894
# Val Loss: 2.7275, Val Acc: 0.6633
#
# Epoch [83/100] - Train Loss: 0.0391, Train Acc: 0.9861
# Val Loss: 2.6981, Val Acc: 0.6587
#
# Epoch [84/100] - Train Loss: 0.0391, Train Acc: 0.9861
# Val Loss: 2.6818, Val Acc: 0.6709
#
# Epoch [85/100] - Train Loss: 0.0369, Train Acc: 0.9867
# Val Loss: 2.6091, Val Acc: 0.6740
#
# Epoch [86/100] - Train Loss: 0.0351, Train Acc: 0.9874
# Val Loss: 2.6965, Val Acc: 0.6691
#
# Epoch [87/100] - Train Loss: 0.0380, Train Acc: 0.9864
# Val Loss: 2.8093, Val Acc: 0.6681
#
# Epoch [88/100] - Train Loss: 0.0407, Train Acc: 0.9846
# Val Loss: 2.8054, Val Acc: 0.6615
#
# Epoch [89/100] - Train Loss: 0.0369, Train Acc: 0.9864
# Val Loss: 2.6900, Val Acc: 0.6714
#
# Epoch [90/100] - Train Loss: 0.0344, Train Acc: 0.9874
# Val Loss: 3.0515, Val Acc: 0.6645
#
# Epoch [91/100] - Train Loss: 0.0356, Train Acc: 0.9879
# Val Loss: 2.6894, Val Acc: 0.6689
#
# Epoch [92/100] - Train Loss: 0.0399, Train Acc: 0.9861
# Val Loss: 2.7071, Val Acc: 0.6666
#
# Epoch [93/100] - Train Loss: 0.0318, Train Acc: 0.9883
# Val Loss: 2.8176, Val Acc: 0.6663
#
# Epoch [94/100] - Train Loss: 0.0369, Train Acc: 0.9854
# Val Loss: 2.9185, Val Acc: 0.6666
#
# Epoch [95/100] - Train Loss: 0.0291, Train Acc: 0.9896
# Val Loss: 2.6364, Val Acc: 0.6673
#
# Epoch [96/100] - Train Loss: 0.0366, Train Acc: 0.9868
# Val Loss: 3.0420, Val Acc: 0.6638
#
# Epoch [97/100] - Train Loss: 0.0294, Train Acc: 0.9899
# Val Loss: 2.9550, Val Acc: 0.6630
#
# Epoch [98/100] - Train Loss: 0.0319, Train Acc: 0.9890
# Val Loss: 3.1166, Val Acc: 0.6668
#
# Epoch [99/100] - Train Loss: 0.0359, Train Acc: 0.9871
# Val Loss: 2.8005, Val Acc: 0.6694
#
# Epoch [100/100] - Train Loss: 0.0315, Train Acc: 0.9892
# Val Loss: 3.4300, Val Acc: 0.6488

# %%
# Plot Loss and Accuracy
plot_loss_and_accuracy(train_losses, val_losses, train_accs, val_accs)

# %%
# Testing
model.eval()
test_loss = 0.0
test_correct = 0
test_total = 0

with torch.no_grad():
    for images_batch, labels_batch in test_loader:
        images_batch = images_batch.to(device)
        labels_batch = labels_batch.to(device)
        
        outputs = model(images_batch)
        loss = criterion(outputs, labels_batch)
        
        test_loss += loss.item() * images_batch.size(0)
        _, predicted = outputs.max(1)
        test_correct += predicted.eq(labels_batch).sum().item()
        test_total += labels_batch.size(0)

test_loss /= len(test_loader.dataset)
test_acc = test_correct / test_total
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 3.3426, Test Acc: 0.6415
